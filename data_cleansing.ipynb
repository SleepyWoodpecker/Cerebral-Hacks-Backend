# %%
import pandas as pd

# %%
customer_df = pd.read_csv("data/customers.csv")
customer_df['user id'] = customer_df['Customer ID']
customer_df = customer_df[[
    'user id', 'Age', 'Gender', 'Item Purchased', 'Category',
    'Location', 'Size', 'Color', 'Season', 'Review Rating', 'Frequency of Purchases', 'Season']]
customer_df
# Out:
#       user id  Age  Gender Item Purchased     Category       Location Size  \
# 0           1   55    Male         Blouse     Clothing       Kentucky    L
# 1           2   19    Male        Sweater     Clothing          Maine    L
# 2           3   50    Male          Jeans     Clothing  Massachusetts    S
# 3           4   21    Male        Sandals     Footwear   Rhode Island    M
# 4           5   45    Male         Blouse     Clothing         Oregon    M
# ...       ...  ...     ...            ...          ...            ...  ...
# 3895     3896   40  Female         Hoodie     Clothing       Virginia    L
# 3896     3897   52  Female       Backpack  Accessories           Iowa    L
# 3897     3898   46  Female           Belt  Accessories     New Jersey    L
# 3898     3899   44  Female          Shoes     Footwear      Minnesota    S
# 3899     3900   52  Female        Handbag  Accessories     California    M
#
# ...

# %%
sales_df = pd.read_csv("data/sales.csv")


sales_df = sales_df[['user id', 'product id', 'Interaction type']].dropna()

sales_df
# Out:
#       user id                        product id Interaction type
# 0         1.0  4c69b61db1fc16e7013b43fc926e502d         purchase
# 1         2.0  66d49bbed043f5be260fa9f7fbff5957             view
# 2         3.0  2c55cae269aebf53838484b0d7dd931a             like
# 3         4.0  18018b6bc416dab347b1b7db79994afa             view
# 4         5.0  e04b990e95bf73bbe6a3fa09785d7cd0             like
# ...       ...                               ...              ...
# 2994   2995.0  f5149cfb8e04d7b30bd7b4eaed6713b8             like
# 2995   2996.0  82318e8acf79bbeb3cf685a2732fb630             view
# 2996   2997.0  19d150365d798db47cccf1622b6ad754         purchase
# 2997   2998.0  136c0aff3ab56bd3d138775fe90ef970             view
# 2998   2999.0  a2c6dd69f022a658c5bcc2b3b52970f2             like
#
# [2871 rows x 3 columns]

# %%
products_df = pd.read_csv("data/products.csv")

products_df['product id'] = products_df['Uniqe Id']

products_df = products_df[["product id", "Product Name", "Category", "About Product", "Selling Price"]]

products_df
# Out:
#                              product id  \
# 0      4c69b61db1fc16e7013b43fc926e502d
# 1      66d49bbed043f5be260fa9f7fbff5957
# 2      2c55cae269aebf53838484b0d7dd931a
# 3      18018b6bc416dab347b1b7db79994afa
# 4      e04b990e95bf73bbe6a3fa09785d7cd0
# ...                                 ...
# 9997   1a22f23576bfdfe5ed6c887dc117aab6
# 9998   e11514dcf1f087887cd5ea0bd646d1fc
# 9999   c00301a38560da2abc89c1f86ce4b267
# 10000  c2928dbf9796ceba44863a2736afb405
# 10001  2bb94aefc3467ed83860e0e2712d5f10
#
#                                             Product Name  \
# 0      DB Longboards CoreFlex Crossbow 41" Bamboo Fib...
# 1      Electronic Snap Circuits Mini Kits Classpack, ...
# 2      3Doodler Create Flexy 3D Printing Filament Ref...
# 3      Guillow Airplane Design Studio with Travel Cas...
# 4                       Woodstock- Collage 500 pc Puzzle
# ...                                                  ...
# 9997   Remedia Publications REM536B Money Activity Bo...
# ...

# %%
df = pd.concat([customer_df, products_df, sales_df], axis=1).dropna()
df = df.loc[:, ~df.columns.duplicated()]
df[:100].to_json('data/data.json')
df
# Out:
#       user id   Age  Gender Item Purchased   Category       Location Size  \
# 0         1.0  55.0    Male         Blouse   Clothing       Kentucky    L
# 1         2.0  19.0    Male        Sweater   Clothing          Maine    L
# 2         3.0  50.0    Male          Jeans   Clothing  Massachusetts    S
# 3         4.0  21.0    Male        Sandals   Footwear   Rhode Island    M
# 4         5.0  45.0    Male         Blouse   Clothing         Oregon    M
# ...       ...   ...     ...            ...        ...            ...  ...
# 2993   2994.0  32.0  Female         Jacket  Outerwear         Kansas    L
# 2994   2995.0  69.0  Female        Sweater   Clothing         Nevada    S
# 2995   2996.0  29.0  Female          Jeans   Clothing       Virginia    M
# 2997   2998.0  41.0  Female        Sweater   Clothing          Idaho    S
# 2998   2999.0  31.0  Female         Hoodie   Clothing         Alaska    M
#
#           Color  Season  Review Rating Frequency of Purchases  \
# ...
